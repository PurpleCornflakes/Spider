# %%
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt

# %%
linkedin = pandas.read_csv('weekly_ratings_by_date_2008-07-09_to_2018-12-20.csv')
kingdomRush = pandas.read_csv('weekly_ratings_by_date_2013-07-01_to_2018-12-20.csv')

# %%
df = linkedin
plt.plot(df['one_star'],'purple')
plt.plot(df['two_star'],'green')
plt.plot(df['three_star'],'yellow')
plt.plot(df['four_star'],'orange')
plt.plot(df['five_star'],'red')
plt.xlim(330,)
# Out:
# (330, 572.25)

# %%
df = kingdomRush
plt.plot(df['one_star'],'purple')
plt.plot(df['two_star'],'green')
plt.plot(df['three_star'],'yellow')
plt.plot(df['four_star'],'orange')
plt.plot(df['five_star'],'red')
plt.xlim(240,)
# Out:
# (240, 299.25)

# %%
df = linkedin
num = df['one_star']+df['two_star']+df['three_star']+df['four_star']+df['five_star']
aver_rating = (df['one_star']+2*df['two_star']+3*df['three_star']+4*df['four_star']+5*df['five_star'])/num
# plt.plot(aver_rating,'black')
# plt.ylim(3,5)
plt.plot(num,'r')

# %%
df = kingdomRush
num = df['one_star']+df['two_star']+df['three_star']+df['four_star']+df['five_star']
aver_rating = (df['one_star']+2*df['two_star']+3*df['three_star']+4*df['four_star']+5*df['five_star'])/num
# plt.plot(aver_rating,'black')
plt.plot(num,'r')
# plt.ylim(3,5)
